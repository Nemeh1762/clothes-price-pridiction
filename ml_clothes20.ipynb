# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:\\Users\\user\\Desktop\\clothes_pre\\clothes_price_prediction_data.csv')

# %%
data = pd.concat([data] * 3, ignore_index=True)
print(data.shape)
# Out:
# (3000, 6)

# %%
print(data.head())
print(data.tail())
print(data.info())
# Out:
#           Brand Category  Color Size Material  Price
# 0   New Balance    Dress  White   XS    Nylon    182
# 1   New Balance    Jeans  Black   XS     Silk     57
# 2  Under Armour    Dress    Red    M     Wool    127
# 3          Nike    Shoes  Green    M   Cotton     77
# 4        Adidas  Sweater  White    M    Nylon    113
#              Brand Category   Color Size   Material  Price
# 2995          Puma    Jeans   Black    L  Polyester    176
# 2996          Puma   Jacket     Red  XXL       Silk    110
# 2997        Reebok  Sweater    Blue   XS      Denim    127
# 2998  Under Armour  Sweater   Black  XXL      Denim     69
# 2999   New Balance   Jacket  Yellow   XS       Wool    174
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Brand     3000 non-null   object
#  1   Category  3000 non-null   object
# ...

# %%
print(data.isnull().sum())
# Out:
# Brand       0
# Category    0
# Color       0
# Size        0
# Material    0
# Price       0
# dtype: int64

# %%
print(data.describe())
# Out:
#              Price
# count  3000.000000
# mean    106.289000
# std      53.677536
# min      10.000000
# 25%      59.750000
# 50%     108.000000
# 75%     150.000000
# max     199.000000

# %%
sns.pairplot(data)
plt.show()

# %%
data.columns
# Out:
# Index(['Brand', 'Category', 'Color', 'Size', 'Material', 'Price'], dtype='object')

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x="Brand", y="Price", data=data, alpha=0.7)
plt.title("(Brand) vs. (Price)")
plt.xlabel("Brand")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x="Category", y="Price", data=data, alpha=0.7)
plt.title("(Category) vs. (Price)")
plt.xlabel("Category")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x="Color", y="Price", data=data, alpha=0.7)
plt.title("(Color) vs.(Price)")
plt.xlabel("Color")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x="Size", y="Price", data=data, alpha=0.7)
plt.title("(Size) vs. (Price)")
plt.xlabel("Size")
plt.ylabel("Price")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x="Material", y="Price", data=data, alpha=0.7)
plt.title("(Material) vs. (Price)")
plt.xlabel("Material")
plt.ylabel("Price")
plt.show()

# %%
columns_to_plot = ["Brand"]

for column in columns_to_plot:
    plt.figure(figsize=(8, 5))
    sns.histplot(data[column], kde=True, bins=30)
    plt.title(f"Distribution of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.show()

# %%
columns_to_plot = ["Category"]

for column in columns_to_plot:
    plt.figure(figsize=(8, 5))
    sns.histplot(data[column], kde=True, bins=30)
    plt.title(f"Distribution of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.show()

# %%
columns_to_plot = ["Color"]

for column in columns_to_plot:
    plt.figure(figsize=(8, 5))
    sns.histplot(data[column], kde=True, bins=30)
    plt.title(f"Distribution of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.show()

# %%
columns_to_plot = ["Size"]

for column in columns_to_plot:
    plt.figure(figsize=(8, 5))
    sns.histplot(data[column], kde=True, bins=30)
    plt.title(f"Distribution of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.show()

# %%
columns_to_plot = ["Material"]

for column in columns_to_plot:
    plt.figure(figsize=(8, 5))
    sns.histplot(data[column], kde=True, bins=30)
    plt.title(f"Distribution of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.show()

# %%
columns_to_plot = ["Price"]

for column in columns_to_plot:
    plt.figure(figsize=(8, 5))
    sns.histplot(data[column], kde=True, bins=30)
    plt.title(f"Distribution of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.show()

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import mean_squared_error

# %%
data.columns
# Out:
# Index(['Brand', 'Category', 'Color', 'Size', 'Material', 'Price'], dtype='object')

# %%
X = data[["Brand", "Category", "Color", "Size", "Material"]]
y = data["Price"]

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)

print("Training set size:", X_train.shape)
print("Test set size:", X_test.shape)
# Out:
# Training set size: (2100, 5)
# Test set size: (600, 5)

# %%
print(X_train.head())

print(y_train.head())
# Out:
#        Brand Category  Color Size Material
# 642   Reebok    Shoes  White   XS    Denim
# 700   Reebok  Sweater  Black    S    Denim
# 226     Nike   Jacket    Red    L    Denim
# 1697  Reebok  T-shirt   Blue  XXL   Cotton
# 1010    Nike   Jacket  White   XL     Silk
# 642     45
# 700     44
# 226     21
# 1697    56
# 1010    98
# Name: Price, dtype: int64

# %%
print(X_test.head())

print(y_test.head())
# Out:
#             Brand Category  Color Size   Material
# 1801  New Balance    Dress  Black   XL      Denim
# 1190       Adidas   Jacket   Blue  XXL      Denim
# 1817  New Balance    Dress  White  XXL  Polyester
# 251          Nike   Jacket  Green   XS  Polyester
# 2505         Puma  T-shirt  Green    M     Cotton
# 1801     48
# 1190    198
# 1817     86
# 251      56
# 2505    191
# Name: Price, dtype: int64

# %%
linear_reg = LinearRegression()

linear_reg.fit(X_train, y_train)

y_pred_linear = linear_reg.predict(X_test)

mse_linear = mean_squared_error(y_test, y_pred_linear)
r2_linear = r2_score(y_test, y_pred_linear)

print(f"Mean Squared Error on Test Set (Linear Regression): {mse_linear}")
print(f"R-squared (Linear Regression): {r2_linear}")
# Out:
# Mean Squared Error on Test Set (Linear Regression): 2900.165235856703
# R-squared (Linear Regression): 0.006618468934433852

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
}

grid_search = GridSearchCV(estimator=RandomForestRegressor(), param_grid=param_grid, cv=5, n_jobs=-1, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

print(f"Best Parameters: {grid_search.best_params_}")

best_model = grid_search.best_estimator_

y_pred_best = best_model.predict(X_test)

mse_best = mean_squared_error(y_test, y_pred_best)
r2_best = r2_score(y_test, y_pred_best)

print(f"Mean Squared Error on Test Set (Best Random Forest): {mse_best}")
print(f"R-squared (Best Random Forest): {r2_best}")
# Out:
# Best Parameters: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 300}
# Mean Squared Error on Test Set (Best Random Forest): 852.1741022383043
# R-squared (Best Random Forest): 0.7081083505347769

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(X_train, y_train)

y_pred_rf = model_rf.predict(X_test)

mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print(f"Mean Squared Error on Test Set (Random Forest): {mse_rf}")
print(f"R-squared (Random Forest): {r2_rf}")
# Out:
# Mean Squared Error on Test Set (Random Forest): 832.6993761242827
# R-squared (Random Forest): 0.7147789474390649

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

param_grid = {
    'n_estimators': [200, 300, 400], 
    'max_depth': [10, 15, 20, None],  
    'min_samples_split': [2, 5, 10],  
    'min_samples_leaf': [1, 2, 4],    
    'bootstrap': [True, False],        
    'max_features': ['auto', 'sqrt', 'log2'] 
}

rf_model = RandomForestRegressor(random_state=42)

grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

grid_search.fit(X_train, y_train)

print(f"Best Parameters: {grid_search.best_params_}")

y_pred_rf = grid_search.predict(X_test)

mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print(f"Mean Squared Error on Test Set (Best Random Forest): {mse_rf}")
print(f"R-squared (Best Random Forest): {r2_rf}")
# Out:
# Fitting 5 folds for each of 648 candidates, totalling 3240 fits
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 1080 fits failed out of a total of 3240.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 444 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
# ...
